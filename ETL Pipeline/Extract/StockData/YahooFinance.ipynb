# %% [markdown]
# ### Extract
# Stock Data from Yahoo Finance

# %%
# %run ../../../_config/base/base.ipynb

# %%
# %run ../../../_util/core/core.ipynb

# %% [markdown]
# # Initialize Spark Session

# %%
spark = SparkSession.builder \
    .master("local[1]") \
    .appName("SparkByExamples.com") \
    .getOrCreate()

# %% [markdown]
# ### Yfinance

# %%
df_dict = {}
for name in LIST_OF_TECH_STOCKS:
    data = yf.Ticker(name).history(interval=INTERVAL_ONEDAY, start=FIRSTDAYOFMONTH_TIME, end=CURR_TIME)
    print(type(data))
    df_dict[name] = spark.createDataFrame(data)
    break

df_dict['AAPL'].printSchema()
df_dict['AAPL'].show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# root
#  |-- Open: double (nullable = true)
#  |-- High: double (nullable = true)
#  |-- Low: double (nullable = true)
#  |-- Close: double (nullable = true)
#  |-- Volume: long (nullable = true)
#  |-- Dividends: long (nullable = true)
#  |-- Stock Splits: long (nullable = true)
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# c:\Users\joshu\Desktop\StockMarketAnalysis\ETL Pipeline\Extract\StockData\YahooFinance.ipynb Cell 7 in <cell line: 9>()
#       <a href='vscode-notebook-cell:/c%3A/Users/joshu/Desktop/StockMarketAnalysis/ETL%20Pipeline/Extract/StockData/YahooFinance.ipynb#W5sZmlsZQ%3D%3D?line=5'>6</a>     break
#       <a href='vscode-notebook-cell:/c%3A/Users/joshu/Desktop/StockMarketAnalysis/ETL%20Pipeline/Extract/StockData/YahooFinance.ipynb#W5sZmlsZQ%3D%3D?line=7'>8</a> df_dict['AAPL'].printSchema()
# ...
